# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations. 
lats = np.random.uniform (low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform (low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitiudes and longitutdes to a list. 
coordinates = list(lat_lngs)

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities. append(city)
        
 #Print the city count to confirm sufficient count.
len(cities)
# Out:
# 770

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
weather_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        weather_description = city_weather["weather"][0]['description']

        # Append the city information into weather_data list.
        weather_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | shache
# Processing Record 3 of Set 1 | contamana
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | esperance
# Processing Record 6 of Set 1 | illapel
# Processing Record 7 of Set 1 | jamestown
# Processing Record 8 of Set 1 | oum hadjer
# Processing Record 9 of Set 1 | bonavista
# Processing Record 10 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 1 | shimoda
# Processing Record 12 of Set 1 | constitucion
# Processing Record 13 of Set 1 | mataura
# Processing Record 14 of Set 1 | atuona
# Processing Record 15 of Set 1 | monrovia
# Processing Record 16 of Set 1 | krasnoselkup
# Processing Record 17 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 18 of Set 1 | arlit
# Processing Record 19 of Set 1 | verkh-usugli
# Processing Record 20 of Set 1 | bethel
# Processing Record 21 of Set 1 | erenhot
# Processing Record 22 of Set 1 | hilo
# Processing Record 23 of Set 1 | vaini
# Processing Record 24 of Set 1 | zmievka
# City not found. Skipping...
# Processing Record 25 of Set 1 | bluff
# Processing Record 26 of Set 1 | nikolskoye
# Processing Record 27 of Set 1 | morondava
# Processing Record 28 of Set 1 | rikitea
# Processing Record 29 of Set 1 | punta arenas
# Processing Record 30 of Set 1 | saint anthony
# Processing Record 31 of Set 1 | kodiak
# Processing Record 32 of Set 1 | cloquet
# Processing Record 33 of Set 1 | praia da vitoria
# Processing Record 34 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 36 of Set 1 | wageningen
# Processing Record 37 of Set 1 | sicamous
# Processing Record 38 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 1 | khatanga
# Processing Record 40 of Set 1 | thompson
# Processing Record 41 of Set 1 | adrar
# Processing Record 42 of Set 1 | antofagasta
# Processing Record 43 of Set 1 | cherskiy
# Processing Record 44 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 45 of Set 1 | flinders
# Processing Record 46 of Set 1 | kavieng
# Processing Record 47 of Set 1 | upata
# Processing Record 48 of Set 1 | la ronge
# Processing Record 49 of Set 1 | eydhafushi
# Processing Record 50 of Set 1 | oromocto
# Processing Record 1 of Set 2 | bredasdorp
# Processing Record 2 of Set 2 | ginir
# Processing Record 3 of Set 2 | east london
# Processing Record 4 of Set 2 | qaanaaq
# Processing Record 5 of Set 2 | silleda
# Processing Record 6 of Set 2 | komsomolskiy
# Processing Record 7 of Set 2 | port-gentil
# Processing Record 8 of Set 2 | norman wells
# Processing Record 9 of Set 2 | ushuaia
# Processing Record 10 of Set 2 | airai
# Processing Record 11 of Set 2 | benghazi
# Processing Record 12 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 2 | kahului
# Processing Record 14 of Set 2 | hobart
# Processing Record 15 of Set 2 | vila franca do campo
# Processing Record 16 of Set 2 | ouallam
# Processing Record 17 of Set 2 | am timan
# Processing Record 18 of Set 2 | new norfolk
# Processing Record 19 of Set 2 | kuli
# Processing Record 20 of Set 2 | port alfred
# Processing Record 21 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 2 | yomitan
# City not found. Skipping...
# Processing Record 23 of Set 2 | challapata
# Processing Record 24 of Set 2 | talnakh
# Processing Record 25 of Set 2 | acari
# Processing Record 26 of Set 2 | cabatuan
# Processing Record 27 of Set 2 | saint george
# Processing Record 28 of Set 2 | kapaa
# Processing Record 29 of Set 2 | laguna
# Processing Record 30 of Set 2 | los llanos de aridane
# Processing Record 31 of Set 2 | camocim
# Processing Record 32 of Set 2 | saint-philippe
# Processing Record 33 of Set 2 | nhulunbuy
# Processing Record 34 of Set 2 | shenjiamen
# Processing Record 35 of Set 2 | faya
# Processing Record 36 of Set 2 | bay roberts
# Processing Record 37 of Set 2 | puerto ayora
# Processing Record 38 of Set 2 | changtu
# Processing Record 39 of Set 2 | butaritari
# Processing Record 40 of Set 2 | sao filipe
# Processing Record 41 of Set 2 | vao
# Processing Record 42 of Set 2 | sitka
# Processing Record 43 of Set 2 | cidreira
# Processing Record 44 of Set 2 | ust-shonosha
# Processing Record 45 of Set 2 | waipawa
# Processing Record 46 of Set 2 | san andres
# Processing Record 47 of Set 2 | ipixuna
# Processing Record 48 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 49 of Set 2 | pelym
# Processing Record 50 of Set 2 | ust-nera
# Processing Record 1 of Set 3 | ternate
# Processing Record 2 of Set 3 | gandajika
# Processing Record 3 of Set 3 | tirumullaivasal
# Processing Record 4 of Set 3 | chimbote
# Processing Record 5 of Set 3 | urubicha
# Processing Record 6 of Set 3 | maceio
# Processing Record 7 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 3 | leningradskiy
# Processing Record 9 of Set 3 | ikalamavony
# Processing Record 10 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 12 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 3 | markova
# Processing Record 14 of Set 3 | salina cruz
# Processing Record 15 of Set 3 | hasaki
# Processing Record 16 of Set 3 | alyangula
# Processing Record 17 of Set 3 | pombas
# Processing Record 18 of Set 3 | ust-kuyga
# Processing Record 19 of Set 3 | tiksi
# Processing Record 20 of Set 3 | meulaboh
# Processing Record 21 of Set 3 | yerbogachen
# Processing Record 22 of Set 3 | klaksvik
# Processing Record 23 of Set 3 | uhlove
# Processing Record 24 of Set 3 | namtsy
# Processing Record 25 of Set 3 | maragogi
# Processing Record 26 of Set 3 | roswell
# Processing Record 27 of Set 3 | aklavik
# Processing Record 28 of Set 3 | tawkar
# City not found. Skipping...
# Processing Record 29 of Set 3 | tasiilaq
# Processing Record 30 of Set 3 | deputatskiy
# Processing Record 31 of Set 3 | san juan
# Processing Record 32 of Set 3 | manokwari
# Processing Record 33 of Set 3 | ostrovnoy
# Processing Record 34 of Set 3 | vinh yen
# Processing Record 35 of Set 3 | mount isa
# Processing Record 36 of Set 3 | olkhovatka
# Processing Record 37 of Set 3 | barrow
# Processing Record 38 of Set 3 | banyo
# Processing Record 39 of Set 3 | krasnovishersk
# Processing Record 40 of Set 3 | aurangabad
# Processing Record 41 of Set 3 | yermish
# Processing Record 42 of Set 3 | cape town
# Processing Record 43 of Set 3 | montepuez
# Processing Record 44 of Set 3 | tahta
# Processing Record 45 of Set 3 | ilulissat
# Processing Record 46 of Set 3 | te anau
# Processing Record 47 of Set 3 | talavera de la reina
# Processing Record 48 of Set 3 | singaparna
# Processing Record 49 of Set 3 | upernavik
# Processing Record 50 of Set 3 | santa cruz
# Processing Record 1 of Set 4 | neftcala
# Processing Record 2 of Set 4 | castro
# Processing Record 3 of Set 4 | dordrecht
# Processing Record 4 of Set 4 | aksu
# Processing Record 5 of Set 4 | ponferrada
# Processing Record 6 of Set 4 | mullovka
# Processing Record 7 of Set 4 | awjilah
# Processing Record 8 of Set 4 | pangnirtung
# Processing Record 9 of Set 4 | lahat
# Processing Record 10 of Set 4 | guozhen
# Processing Record 11 of Set 4 | hermanus
# Processing Record 12 of Set 4 | hambantota
# Processing Record 13 of Set 4 | rabo de peixe
# Processing Record 14 of Set 4 | arraial do cabo
# Processing Record 15 of Set 4 | mocuba
# Processing Record 16 of Set 4 | san patricio
# Processing Record 17 of Set 4 | zlatoustovsk
# City not found. Skipping...
# Processing Record 18 of Set 4 | bonthe
# Processing Record 19 of Set 4 | souillac
# Processing Record 20 of Set 4 | tsienyane
# City not found. Skipping...
# Processing Record 21 of Set 4 | korla
# Processing Record 22 of Set 4 | dikson
# Processing Record 23 of Set 4 | saskylakh
# Processing Record 24 of Set 4 | severo-kurilsk
# Processing Record 25 of Set 4 | gashua
# Processing Record 26 of Set 4 | taoudenni
# Processing Record 27 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 4 | yumbel
# Processing Record 29 of Set 4 | sindand
# City not found. Skipping...
# Processing Record 30 of Set 4 | bambanglipuro
# Processing Record 31 of Set 4 | san ciro de acosta
# Processing Record 32 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 33 of Set 4 | norfolk
# Processing Record 34 of Set 4 | berdigestyakh
# Processing Record 35 of Set 4 | coquimbo
# Processing Record 36 of Set 4 | puqi
# Processing Record 37 of Set 4 | kuah
# Processing Record 38 of Set 4 | srednekolymsk
# Processing Record 39 of Set 4 | the valley
# Processing Record 40 of Set 4 | bengkalis
# City not found. Skipping...
# Processing Record 41 of Set 4 | walvis bay
# Processing Record 42 of Set 4 | misratah
# Processing Record 43 of Set 4 | arzamas
# Processing Record 44 of Set 4 | altay
# Processing Record 45 of Set 4 | utiroa
# City not found. Skipping...
# Processing Record 46 of Set 4 | craig
# Processing Record 47 of Set 4 | lebu
# Processing Record 48 of Set 4 | lokosovo
# Processing Record 49 of Set 4 | kaeo
# Processing Record 50 of Set 4 | touros
# Processing Record 1 of Set 5 | mbandaka
# Processing Record 2 of Set 5 | loukhi
# Processing Record 3 of Set 5 | bengkulu
# Processing Record 4 of Set 5 | sumbe
# Processing Record 5 of Set 5 | kidal
# Processing Record 6 of Set 5 | avera
# Processing Record 7 of Set 5 | broken hill
# Processing Record 8 of Set 5 | arvika
# Processing Record 9 of Set 5 | vargashi
# Processing Record 10 of Set 5 | kaitangata
# Processing Record 11 of Set 5 | avarua
# Processing Record 12 of Set 5 | inongo
# Processing Record 13 of Set 5 | lucapa
# Processing Record 14 of Set 5 | pasighat
# Processing Record 15 of Set 5 | horconcitos
# Processing Record 16 of Set 5 | ribeira grande
# Processing Record 17 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 18 of Set 5 | chuy
# Processing Record 19 of Set 5 | sol-iletsk
# Processing Record 20 of Set 5 | qui nhon
# Processing Record 21 of Set 5 | cockburn town
# Processing Record 22 of Set 5 | xam nua
# Processing Record 23 of Set 5 | port blair
# Processing Record 24 of Set 5 | tungkang
# City not found. Skipping...
# Processing Record 25 of Set 5 | cabo san lucas
# Processing Record 26 of Set 5 | pathein
# Processing Record 27 of Set 5 | yellowknife
# Processing Record 28 of Set 5 | luderitz
# Processing Record 29 of Set 5 | nalut
# Processing Record 30 of Set 5 | nakasongola
# Processing Record 31 of Set 5 | verkhnyaya inta
# Processing Record 32 of Set 5 | saint-pierre
# Processing Record 33 of Set 5 | tessalit
# Processing Record 34 of Set 5 | urengoy
# Processing Record 35 of Set 5 | tarata
# Processing Record 36 of Set 5 | dauphin
# Processing Record 37 of Set 5 | blackwater
# Processing Record 38 of Set 5 | simbahan
# Processing Record 39 of Set 5 | verkhnevilyuysk
# Processing Record 40 of Set 5 | hithadhoo
# Processing Record 41 of Set 5 | mar del plata
# Processing Record 42 of Set 5 | mahibadhoo
# Processing Record 43 of Set 5 | lorengau
# Processing Record 44 of Set 5 | hunza
# City not found. Skipping...
# Processing Record 45 of Set 5 | hervey bay
# Processing Record 46 of Set 5 | san quintin
# Processing Record 47 of Set 5 | juneau
# Processing Record 48 of Set 5 | qarqin
# Processing Record 49 of Set 5 | sri aman
# Processing Record 50 of Set 5 | zhezkazgan
# Processing Record 1 of Set 6 | penzance
# Processing Record 2 of Set 6 | longyearbyen
# Processing Record 3 of Set 6 | portel
# Processing Record 4 of Set 6 | tuktoyaktuk
# Processing Record 5 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 6 | oster
# Processing Record 7 of Set 6 | sao joao da barra
# Processing Record 8 of Set 6 | ati
# Processing Record 9 of Set 6 | lalmohan
# Processing Record 10 of Set 6 | brae
# Processing Record 11 of Set 6 | saldanha
# Processing Record 12 of Set 6 | biltine
# Processing Record 13 of Set 6 | bata
# Processing Record 14 of Set 6 | la rioja
# Processing Record 15 of Set 6 | ahipara
# Processing Record 16 of Set 6 | nanortalik
# Processing Record 17 of Set 6 | burlington
# Processing Record 18 of Set 6 | zacatepec
# Processing Record 19 of Set 6 | torbay
# Processing Record 20 of Set 6 | kollegal
# Processing Record 21 of Set 6 | ponta do sol
# Processing Record 22 of Set 6 | jiexiu
# Processing Record 23 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 6 | fortuna
# Processing Record 25 of Set 6 | ewa beach
# Processing Record 26 of Set 6 | port hardy
# Processing Record 27 of Set 6 | mecca
# Processing Record 28 of Set 6 | viedma
# Processing Record 29 of Set 6 | kieta
# Processing Record 30 of Set 6 | victoria
# Processing Record 31 of Set 6 | leshukonskoye
# Processing Record 32 of Set 6 | jiangmen
# Processing Record 33 of Set 6 | lompoc
# Processing Record 34 of Set 6 | baherden
# Processing Record 35 of Set 6 | faanui
# Processing Record 36 of Set 6 | cheuskiny
# City not found. Skipping...
# Processing Record 37 of Set 6 | hihifo
# City not found. Skipping...
# Processing Record 38 of Set 6 | bismarck
# Processing Record 39 of Set 6 | husavik
# Processing Record 40 of Set 6 | abu samrah
# Processing Record 41 of Set 6 | sur
# Processing Record 42 of Set 6 | caravelas
# Processing Record 43 of Set 6 | georgetown
# Processing Record 44 of Set 6 | mahebourg
# Processing Record 45 of Set 6 | villazon
# Processing Record 46 of Set 6 | iqaluit
# Processing Record 47 of Set 6 | port elizabeth
# Processing Record 48 of Set 6 | clyde river
# Processing Record 49 of Set 6 | kavaratti
# Processing Record 50 of Set 6 | ambilobe
# Processing Record 1 of Set 7 | palmer
# Processing Record 2 of Set 7 | artyk
# City not found. Skipping...
# Processing Record 3 of Set 7 | bayangol
# Processing Record 4 of Set 7 | coahuayana
# Processing Record 5 of Set 7 | druzhba
# Processing Record 6 of Set 7 | odweyne
# Processing Record 7 of Set 7 | maniitsoq
# Processing Record 8 of Set 7 | itaueira
# Processing Record 9 of Set 7 | hamilton
# Processing Record 10 of Set 7 | castricum
# Processing Record 11 of Set 7 | aksarka
# Processing Record 12 of Set 7 | jinchang
# Processing Record 13 of Set 7 | klyuchi
# Processing Record 14 of Set 7 | belaya gora
# Processing Record 15 of Set 7 | jefferson city
# Processing Record 16 of Set 7 | atbasar
# Processing Record 17 of Set 7 | north bend
# Processing Record 18 of Set 7 | lerik
# Processing Record 19 of Set 7 | kerman
# Processing Record 20 of Set 7 | roald
# Processing Record 21 of Set 7 | salinopolis
# Processing Record 22 of Set 7 | khani
# Processing Record 23 of Set 7 | sibu
# Processing Record 24 of Set 7 | garca
# Processing Record 25 of Set 7 | beyneu
# Processing Record 26 of Set 7 | paamiut
# Processing Record 27 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 28 of Set 7 | moerai
# Processing Record 29 of Set 7 | geresk
# City not found. Skipping...
# Processing Record 30 of Set 7 | palauig
# Processing Record 31 of Set 7 | ecatepec
# Processing Record 32 of Set 7 | teahupoo
# Processing Record 33 of Set 7 | solnechnyy
# Processing Record 34 of Set 7 | camopi
# Processing Record 35 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 36 of Set 7 | micheweni
# Processing Record 37 of Set 7 | havelock
# Processing Record 38 of Set 7 | sampit
# Processing Record 39 of Set 7 | carupano
# Processing Record 40 of Set 7 | kawhia
# Processing Record 41 of Set 7 | pisco
# Processing Record 42 of Set 7 | tambovka
# Processing Record 43 of Set 7 | turayf
# Processing Record 44 of Set 7 | shakawe
# Processing Record 45 of Set 7 | binzhou
# Processing Record 46 of Set 7 | lata
# Processing Record 47 of Set 7 | siuna
# Processing Record 48 of Set 7 | hobyo
# Processing Record 49 of Set 7 | damghan
# Processing Record 50 of Set 7 | namatanai
# Processing Record 1 of Set 8 | san cristobal
# Processing Record 2 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 3 of Set 8 | isla mujeres
# Processing Record 4 of Set 8 | wulanhaote
# City not found. Skipping...
# Processing Record 5 of Set 8 | bandarbeyla
# Processing Record 6 of Set 8 | narsaq
# Processing Record 7 of Set 8 | pittsfield
# Processing Record 8 of Set 8 | lisakovsk
# Processing Record 9 of Set 8 | male
# Processing Record 10 of Set 8 | acapulco
# Processing Record 11 of Set 8 | zhigansk
# Processing Record 12 of Set 8 | acarau
# Processing Record 13 of Set 8 | mitsamiouli
# Processing Record 14 of Set 8 | alekseyevsk
# Processing Record 15 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 16 of Set 8 | weston
# Processing Record 17 of Set 8 | digby
# Processing Record 18 of Set 8 | lucea
# Processing Record 19 of Set 8 | yulara
# Processing Record 20 of Set 8 | wanxian
# Processing Record 21 of Set 8 | vestmannaeyjar
# Processing Record 22 of Set 8 | takoradi
# Processing Record 23 of Set 8 | nelson bay
# Processing Record 24 of Set 8 | peno
# Processing Record 25 of Set 8 | nikolayevka
# Processing Record 26 of Set 8 | bubaque
# Processing Record 27 of Set 8 | santa cruz de tenerife
# Processing Record 28 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 8 | bambous virieux
# Processing Record 30 of Set 8 | palimbang
# Processing Record 31 of Set 8 | mogadishu
# Processing Record 32 of Set 8 | port macquarie
# Processing Record 33 of Set 8 | kitimat
# Processing Record 34 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 35 of Set 8 | pevek
# Processing Record 36 of Set 8 | pascagoula
# Processing Record 37 of Set 8 | hofn
# Processing Record 38 of Set 8 | necochea
# Processing Record 39 of Set 8 | lagoa
# Processing Record 40 of Set 8 | mount gambier
# Processing Record 41 of Set 8 | marzuq
# Processing Record 42 of Set 8 | hammerfest
# Processing Record 43 of Set 8 | saurimo
# Processing Record 44 of Set 8 | svetlyy
# Processing Record 45 of Set 8 | santa maria
# Processing Record 46 of Set 8 | chokurdakh
# Processing Record 47 of Set 8 | carnarvon
# Processing Record 48 of Set 8 | beringovskiy
# Processing Record 49 of Set 8 | hot springs
# Processing Record 50 of Set 8 | bathsheba
# Processing Record 1 of Set 9 | felanitx
# Processing Record 2 of Set 9 | salalah
# Processing Record 3 of Set 9 | tukrah
# Processing Record 4 of Set 9 | palma del rio
# Processing Record 5 of Set 9 | kamra
# Processing Record 6 of Set 9 | barra do garcas
# Processing Record 7 of Set 9 | port lincoln
# Processing Record 8 of Set 9 | osypenko
# Processing Record 9 of Set 9 | huarmey
# Processing Record 10 of Set 9 | chitral
# Processing Record 11 of Set 9 | gayeri
# Processing Record 12 of Set 9 | akyab
# Processing Record 13 of Set 9 | carauari
# Processing Record 14 of Set 9 | umm kaddadah
# Processing Record 15 of Set 9 | west bay
# Processing Record 16 of Set 9 | svetlogorsk
# Processing Record 17 of Set 9 | ovsyanka
# Processing Record 18 of Set 9 | yangambi
# Processing Record 19 of Set 9 | kongolo
# Processing Record 20 of Set 9 | ulaangom
# Processing Record 21 of Set 9 | pacific grove
# Processing Record 22 of Set 9 | sept-iles
# Processing Record 23 of Set 9 | karratha
# Processing Record 24 of Set 9 | sabzevar
# Processing Record 25 of Set 9 | sayat
# Processing Record 26 of Set 9 | mananara
# Processing Record 27 of Set 9 | taltal
# Processing Record 28 of Set 9 | merauke
# Processing Record 29 of Set 9 | fairbanks
# Processing Record 30 of Set 9 | dwarka
# Processing Record 31 of Set 9 | isangel
# Processing Record 32 of Set 9 | price
# Processing Record 33 of Set 9 | candolim
# Processing Record 34 of Set 9 | bac lieu
# Processing Record 35 of Set 9 | fenyi
# Processing Record 36 of Set 9 | sioux lookout
# Processing Record 37 of Set 9 | dzhusaly
# City not found. Skipping...
# Processing Record 38 of Set 9 | sabang
# Processing Record 39 of Set 9 | tuatapere
# Processing Record 40 of Set 9 | sangar
# Processing Record 41 of Set 9 | yuncheng
# Processing Record 42 of Set 9 | kabompo
# Processing Record 43 of Set 9 | barentu
# Processing Record 44 of Set 9 | provideniya
# Processing Record 45 of Set 9 | hay river
# Processing Record 46 of Set 9 | russell
# Processing Record 47 of Set 9 | wahran
# City not found. Skipping...
# Processing Record 48 of Set 9 | kursumlija
# Processing Record 49 of Set 9 | plastun
# Processing Record 50 of Set 9 | batagay-alyta
# Processing Record 1 of Set 10 | olinda
# Processing Record 2 of Set 10 | prainha
# Processing Record 3 of Set 10 | soure
# Processing Record 4 of Set 10 | imeni babushkina
# Processing Record 5 of Set 10 | high rock
# Processing Record 6 of Set 10 | olafsvik
# Processing Record 7 of Set 10 | aban
# Processing Record 8 of Set 10 | nouadhibou
# Processing Record 9 of Set 10 | escanaba
# Processing Record 10 of Set 10 | mutoko
# Processing Record 11 of Set 10 | lar gerd
# City not found. Skipping...
# Processing Record 12 of Set 10 | formosa
# Processing Record 13 of Set 10 | aswan
# Processing Record 14 of Set 10 | kindu
# Processing Record 15 of Set 10 | dhidhdhoo
# Processing Record 16 of Set 10 | slavutych
# Processing Record 17 of Set 10 | erdenet
# Processing Record 18 of Set 10 | vila velha
# Processing Record 19 of Set 10 | businga
# Processing Record 20 of Set 10 | kyzyl-suu
# Processing Record 21 of Set 10 | vanavara
# Processing Record 22 of Set 10 | high level
# Processing Record 23 of Set 10 | le port
# Processing Record 24 of Set 10 | cocorit
# Processing Record 25 of Set 10 | lalomanu
# City not found. Skipping...
# Processing Record 26 of Set 10 | grand-lahou
# Processing Record 27 of Set 10 | trussville
# Processing Record 28 of Set 10 | bosaso
# Processing Record 29 of Set 10 | lavrentiya
# Processing Record 30 of Set 10 | bahia honda
# Processing Record 31 of Set 10 | jabiru
# City not found. Skipping...
# Processing Record 32 of Set 10 | changji
# Processing Record 33 of Set 10 | usinsk
# Processing Record 34 of Set 10 | muzhi
# Processing Record 35 of Set 10 | yarada
# Processing Record 36 of Set 10 | yueyang
# Processing Record 37 of Set 10 | cooma
# Processing Record 38 of Set 10 | port moresby
# Processing Record 39 of Set 10 | katsuura
# Processing Record 40 of Set 10 | taseyevo
# Processing Record 41 of Set 10 | lander
# Processing Record 42 of Set 10 | atambua
# Processing Record 43 of Set 10 | chingirlau
# Processing Record 44 of Set 10 | fort nelson
# Processing Record 45 of Set 10 | lasa
# Processing Record 46 of Set 10 | wladyslawowo
# Processing Record 47 of Set 10 | dingle
# Processing Record 48 of Set 10 | alexandria
# Processing Record 49 of Set 10 | kamenka
# Processing Record 50 of Set 10 | namibe
# Processing Record 1 of Set 11 | basyanovskiy
# City not found. Skipping...
# Processing Record 2 of Set 11 | mezen
# Processing Record 3 of Set 11 | richards bay
# Processing Record 4 of Set 11 | chagoda
# Processing Record 5 of Set 11 | grafton
# Processing Record 6 of Set 11 | sorland
# Processing Record 7 of Set 11 | breclav
# Processing Record 8 of Set 11 | beloha
# Processing Record 9 of Set 11 | limon
# Processing Record 10 of Set 11 | ikungi
# Processing Record 11 of Set 11 | rocha
# Processing Record 12 of Set 11 | murmansk
# Processing Record 13 of Set 11 | kashi
# Processing Record 14 of Set 11 | huambo
# Processing Record 15 of Set 11 | banda aceh
# Processing Record 16 of Set 11 | ojinaga
# Processing Record 17 of Set 11 | huilong
# Processing Record 18 of Set 11 | flin flon
# Processing Record 19 of Set 11 | mana
# Processing Record 20 of Set 11 | harwich
# Processing Record 21 of Set 11 | xining
# Processing Record 22 of Set 11 | pangody
# Processing Record 23 of Set 11 | boyolangu
# Processing Record 24 of Set 11 | ruteng
# Processing Record 25 of Set 11 | bluefield
# Processing Record 26 of Set 11 | urumqi
# Processing Record 27 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 28 of Set 11 | biak
# Processing Record 29 of Set 11 | mount barker
# Processing Record 30 of Set 11 | shirokiy
# Processing Record 31 of Set 11 | cockburn harbour
# City not found. Skipping...
# Processing Record 32 of Set 11 | saint-augustin
# Processing Record 33 of Set 11 | lusambo
# Processing Record 34 of Set 11 | poli
# Processing Record 35 of Set 11 | kruisfontein
# Processing Record 36 of Set 11 | murgab
# Processing Record 37 of Set 11 | tuy hoa
# Processing Record 38 of Set 11 | uray
# Processing Record 39 of Set 11 | lubango
# Processing Record 40 of Set 11 | camana
# Processing Record 41 of Set 11 | paracuaro
# Processing Record 42 of Set 11 | naze
# Processing Record 43 of Set 11 | krasnyy yar
# Processing Record 44 of Set 11 | orocue
# Processing Record 45 of Set 11 | la rochelle
# Processing Record 46 of Set 11 | dunedin
# Processing Record 47 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 48 of Set 11 | green haven
# Processing Record 49 of Set 11 | rabnita
# City not found. Skipping...
# Processing Record 50 of Set 11 | sidi bu zayd
# City not found. Skipping...
# Processing Record 1 of Set 12 | promyshlennyy
# Processing Record 2 of Set 12 | lebanon
# Processing Record 3 of Set 12 | mahanoro
# Processing Record 4 of Set 12 | palana
# Processing Record 5 of Set 12 | makushino
# Processing Record 6 of Set 12 | malwan
# City not found. Skipping...
# Processing Record 7 of Set 12 | karasjok
# Processing Record 8 of Set 12 | ucluelet
# Processing Record 9 of Set 12 | mishan
# Processing Record 10 of Set 12 | codrington
# Processing Record 11 of Set 12 | yunyang
# Processing Record 12 of Set 12 | shaoyang
# Processing Record 13 of Set 12 | tilichiki
# Processing Record 14 of Set 12 | kingori
# Processing Record 15 of Set 12 | jalu
# Processing Record 16 of Set 12 | tazovskiy
# Processing Record 17 of Set 12 | stara synyava
# Processing Record 18 of Set 12 | padang
# Processing Record 19 of Set 12 | tagusao
# Processing Record 20 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 21 of Set 12 | sandwick
# Processing Record 22 of Set 12 | gornopravdinsk
# Processing Record 23 of Set 12 | moose factory
# Processing Record 24 of Set 12 | avila
# Processing Record 25 of Set 12 | asbe teferi
# Processing Record 26 of Set 12 | guerrero negro
# Processing Record 27 of Set 12 | limbang
# Processing Record 28 of Set 12 | khandyga
# Processing Record 29 of Set 12 | vardo
# Processing Record 30 of Set 12 | aketi
# Processing Record 31 of Set 12 | hounde
# Processing Record 32 of Set 12 | mersing
# Processing Record 33 of Set 12 | sinnamary
# Processing Record 34 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 35 of Set 12 | chicama
# Processing Record 36 of Set 12 | ventspils
# Processing Record 37 of Set 12 | nadvoitsy
# Processing Record 38 of Set 12 | bilibino
# Processing Record 39 of Set 12 | iralaya
# Processing Record 40 of Set 12 | sambava
# Processing Record 41 of Set 12 | karamay
# City not found. Skipping...
# Processing Record 42 of Set 12 | gangarampur
# Processing Record 43 of Set 12 | warrnambool
# Processing Record 44 of Set 12 | san vicente
# Processing Record 45 of Set 12 | comodoro rivadavia
# Processing Record 46 of Set 12 | miri
# Processing Record 47 of Set 12 | shingu
# Processing Record 48 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 49 of Set 12 | ancud
# Processing Record 50 of Set 12 | macaboboni
# City not found. Skipping...
# Processing Record 1 of Set 13 | corinto
# Processing Record 2 of Set 13 | beian
# Processing Record 3 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 4 of Set 13 | lappeenranta
# Processing Record 5 of Set 13 | presidencia roque saenz pena
# Processing Record 6 of Set 13 | scarborough
# Processing Record 7 of Set 13 | mayo
# Processing Record 8 of Set 13 | ardakan
# Processing Record 9 of Set 13 | kjollefjord
# Processing Record 10 of Set 13 | kulhudhuffushi
# Processing Record 11 of Set 13 | ishinomaki
# Processing Record 12 of Set 13 | bagua grande
# Processing Record 13 of Set 13 | vangaindrano
# Processing Record 14 of Set 13 | naifaru
# Processing Record 15 of Set 13 | grindavik
# Processing Record 16 of Set 13 | cayenne
# Processing Record 17 of Set 13 | paso de patria
# Processing Record 18 of Set 13 | mokolo
# Processing Record 19 of Set 13 | opuwo
# Processing Record 20 of Set 13 | makat
# Processing Record 21 of Set 13 | samarai
# Processing Record 22 of Set 13 | saint-francois
# Processing Record 23 of Set 13 | green valley
# Processing Record 24 of Set 13 | sueyoshi
# Processing Record 25 of Set 13 | coihaique
# Processing Record 26 of Set 13 | vilhena
# Processing Record 27 of Set 13 | atar
# Processing Record 28 of Set 13 | kampli
# Processing Record 29 of Set 13 | grand gaube
# Processing Record 30 of Set 13 | dukat
# Processing Record 31 of Set 13 | lagunas
# Processing Record 32 of Set 13 | khorol
# Processing Record 33 of Set 13 | batticaloa
# Processing Record 34 of Set 13 | apiai
# Processing Record 35 of Set 13 | rossosh
# Processing Record 36 of Set 13 | nome
# Processing Record 37 of Set 13 | aloleng
# Processing Record 38 of Set 13 | mareeba
# Processing Record 39 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 40 of Set 13 | esqueda
# Processing Record 41 of Set 13 | bur gabo
# City not found. Skipping...
# Processing Record 42 of Set 13 | chachapoyas
# Processing Record 43 of Set 13 | palma
# Processing Record 44 of Set 13 | magaria
# Processing Record 45 of Set 13 | kuybyshevo
# Processing Record 46 of Set 13 | millington
# Processing Record 47 of Set 13 | port-cartier
# Processing Record 48 of Set 13 | haimen
# Processing Record 49 of Set 13 | tura
# Processing Record 50 of Set 13 | mirnyy
# Processing Record 1 of Set 14 | mityana
# Processing Record 2 of Set 14 | terrace bay
# Processing Record 3 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 4 of Set 14 | punta alta
# Processing Record 5 of Set 14 | senno
# Processing Record 6 of Set 14 | kilindoni
# Processing Record 7 of Set 14 | yumen
# Processing Record 8 of Set 14 | sorsk
# Processing Record 9 of Set 14 | beitbridge
# Processing Record 10 of Set 14 | labutta
# City not found. Skipping...
# Processing Record 11 of Set 14 | amapa
# Processing Record 12 of Set 14 | malanville
# Processing Record 13 of Set 14 | geraldton
# Processing Record 14 of Set 14 | hovd
# Processing Record 15 of Set 14 | goure
# Processing Record 16 of Set 14 | la mana
# Processing Record 17 of Set 14 | saint-ambroise
# Processing Record 18 of Set 14 | alice springs
# Processing Record 19 of Set 14 | fort-shevchenko
# Processing Record 20 of Set 14 | coos bay
# Processing Record 21 of Set 14 | khilok
# Processing Record 22 of Set 14 | djambala
# Processing Record 23 of Set 14 | tocopilla
# Processing Record 24 of Set 14 | ust-omchug
# Processing Record 25 of Set 14 | lewiston
# Processing Record 26 of Set 14 | bartica
# Processing Record 27 of Set 14 | scottsburgh
# City not found. Skipping...
# Processing Record 28 of Set 14 | denizli
# Processing Record 29 of Set 14 | oga
# Processing Record 30 of Set 14 | sidi ali
# Processing Record 31 of Set 14 | puerto baquerizo moreno
# Processing Record 32 of Set 14 | aguia branca
# Processing Record 33 of Set 14 | dzerzhinskoye
# Processing Record 34 of Set 14 | key west
# Processing Record 35 of Set 14 | kiama
# Processing Record 36 of Set 14 | leh
# Processing Record 37 of Set 14 | padampur
# Processing Record 38 of Set 14 | lalibela
# Processing Record 39 of Set 14 | jarjis
# City not found. Skipping...
# Processing Record 40 of Set 14 | conde
# Processing Record 41 of Set 14 | zhuhai
# Processing Record 42 of Set 14 | bonnyville
# Processing Record 43 of Set 14 | kingaroy
# Processing Record 44 of Set 14 | harper
# Processing Record 45 of Set 14 | cape elizabeth
# City not found. Skipping...
# Processing Record 46 of Set 14 | borba
# Processing Record 47 of Set 14 | milkovo
# Processing Record 48 of Set 14 | cravo norte
# Processing Record 49 of Set 14 | snezhnogorsk
# Processing Record 50 of Set 14 | holland
# Processing Record 1 of Set 15 | zunyi
# Processing Record 2 of Set 15 | asfi
# Processing Record 3 of Set 15 | conway
# Processing Record 4 of Set 15 | kot samaba
# Processing Record 5 of Set 15 | northam
# Processing Record 6 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 7 of Set 15 | port hedland
# Processing Record 8 of Set 15 | obo
# Processing Record 9 of Set 15 | shahrud
# Processing Record 10 of Set 15 | lapithos
# Processing Record 11 of Set 15 | sterling
# Processing Record 12 of Set 15 | slave lake
# Processing Record 13 of Set 15 | wasilla
# Processing Record 14 of Set 15 | rockport
# Processing Record 15 of Set 15 | tianpeng
# Processing Record 16 of Set 15 | kununurra
# Processing Record 17 of Set 15 | san jeronimo
# Processing Record 18 of Set 15 | dedougou
# Processing Record 19 of Set 15 | dunda
# Processing Record 20 of Set 15 | mosquera
# Processing Record 21 of Set 15 | half moon bay
# Processing Record 22 of Set 15 | stokmarknes
# Processing Record 23 of Set 15 | poyarkovo
# Processing Record 24 of Set 15 | sao marcos
# Processing Record 25 of Set 15 | bien hoa
# Processing Record 26 of Set 15 | barra mansa
# Processing Record 27 of Set 15 | cheyenne
# Processing Record 28 of Set 15 | baoying
# Processing Record 29 of Set 15 | zonalnaya stantsiya
# Processing Record 30 of Set 15 | ginda
# Processing Record 31 of Set 15 | haines junction
# Processing Record 32 of Set 15 | wanaka
# Processing Record 33 of Set 15 | chapais
# Processing Record 34 of Set 15 | wanning
# Processing Record 35 of Set 15 | dubbo
# Processing Record 36 of Set 15 | mount pleasant
# Processing Record 37 of Set 15 | normandin
# Processing Record 38 of Set 15 | nara
# Processing Record 39 of Set 15 | kenai
# Processing Record 40 of Set 15 | waitakere
# Processing Record 41 of Set 15 | jinxiang
# Processing Record 42 of Set 15 | sisimiut
# Processing Record 43 of Set 15 | sabya
# Processing Record 44 of Set 15 | carahue
# Processing Record 45 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 46 of Set 15 | broome
# Processing Record 47 of Set 15 | lodja
# Processing Record 48 of Set 15 | poum
# Processing Record 49 of Set 15 | tsumeb
# Processing Record 50 of Set 15 | gazni
# City not found. Skipping...
# Processing Record 1 of Set 16 | cobourg
# Processing Record 2 of Set 16 | puerto escondido
# Processing Record 3 of Set 16 | mnogovershinnyy
# Processing Record 4 of Set 16 | claremore
# Processing Record 5 of Set 16 | teya
# Processing Record 6 of Set 16 | sobolevo
# Processing Record 7 of Set 16 | tokur
# Processing Record 8 of Set 16 | esso
# Processing Record 9 of Set 16 | magadan
# Processing Record 10 of Set 16 | kargopol
# Processing Record 11 of Set 16 | kloulklubed
# Processing Record 12 of Set 16 | lakatoro
# Processing Record 13 of Set 16 | subaytilah
# City not found. Skipping...
# Processing Record 14 of Set 16 | borgo san dalmazzo
# Processing Record 15 of Set 16 | keetmanshoop
# Processing Record 16 of Set 16 | gorssel
# Processing Record 17 of Set 16 | sedona
# Processing Record 18 of Set 16 | rafaela
# Processing Record 19 of Set 16 | liverpool
# Processing Record 20 of Set 16 | gaziantep
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
weather_data_df = pd.DataFrame(weather_data)
weather_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Albany      US  42.6001  -73.9662     33.01        69         100
# 1      Shache      CN  38.4167   77.2406     32.59        60           0
# 2   Contamana      PE  -7.3333  -75.0167     76.30        82         100
# 3   Busselton      AU -33.6500  115.3333     71.01        44          89
# 4   Esperance      AU -33.8667  121.9000     68.00        42          99
# 5     Illapel      CL -31.6308  -71.1653     55.47        67           0
# 6   Jamestown      US  42.0970  -79.2353     37.99        75           1
# 7  Oum Hadjer      TD  13.2954   19.6966     65.05        25           0
# 8   Bonavista      CA  48.6499  -53.1147     30.00        93         100
# 9     Shimoda      JP  34.6667  138.9500     55.40        54           0
#
#    Wind Speed Current Description
# 0        3.11     overcast clouds
# 1        4.68           clear sky
# 2        4.74     overcast clouds
# 3        4.00     overcast clouds
# 4       14.97     overcast clouds
# 5        1.36           clear sky
# 6        8.05           clear sky
# 7       10.87           clear sky
# 8        1.14     overcast clouds
# 9        8.05           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the Weather_Data into a CSV.
weather_data_df.to_csv(output_data_file, index_label="City_ID")
